# %%
import torch
#assert '.'.join(torch.__version__.split('.')[:2]) == '1.4'
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from torch.utils.data import sampler

import torchvision.datasets as dset
import torchvision.transforms as T

import numpy as np
import os
# the fourth v100 GPU
os.environ['CUDA_VISIBLE_DEVICES'] = '3'
device = 'cuda' if torch.cuda.is_available() else 'cpu'

print_every = 100

# %%
NUM_TRAIN = 49000

# The torchvision.transforms package provides tools for preprocessing data
# and for performing data augmentation; here we set up a transform to
# preprocess the data by subtracting the mean RGB value and dividing by the
# standard deviation of each RGB value; we've hardcoded the mean and std.
transform = T.Compose([
                T.ToTensor(),
                T.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010))
            ])

# We set up a Dataset object for each split (train / val / test); Datasets load
# training examples one at a time, so we wrap each Dataset in a DataLoader which
# iterates through the Dataset and forms minibatches. We divide the CIFAR-10
# training set into train and val sets by passing a Sampler object to the
# DataLoader telling how it should sample from the underlying Dataset.
cifar10_train = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                             transform=transform)
loader_train = DataLoader(cifar10_train, batch_size=64, 
                          sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN)))

cifar10_val = dset.CIFAR10('./cs231n/datasets', train=True, download=True,
                           transform=transform)
loader_val = DataLoader(cifar10_val, batch_size=64, 
                        sampler=sampler.SubsetRandomSampler(range(NUM_TRAIN, 50000)))

cifar10_test = dset.CIFAR10('./cs231n/datasets', train=False, download=True, 
                            transform=transform)
loader_test = DataLoader(cifar10_test, batch_size=64)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def check_accuracy_part34(loader, model):
    if loader.dataset.train:
        print('Checking accuracy on validation set')
    else:
        print('Checking accuracy on test set')   
    num_correct = 0
    num_samples = 0
    model.eval()  # set model to evaluation mode
    with torch.no_grad():
        for x, y in loader:
            x = x.to(device=device, dtype=torch.float)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)
            scores = model(x)
            _, preds = scores.max(1)
            num_correct += (preds == y).sum()
            num_samples += preds.size(0)
        acc = float(num_correct) / num_samples
        print('Got %d / %d correct (%.2f)' % (num_correct, num_samples, 100 * acc))

# %%
def train_part34(model, optimizer, epochs=1):
    """
    Train a model on CIFAR-10 using the PyTorch Module API.
    
    Inputs:
    - model: A PyTorch Module giving the model to train.
    - optimizer: An Optimizer object we will use to train the model
    - epochs: (Optional) A Python integer giving the number of epochs to train for
    
    Returns: Nothing, but prints model accuracies during training.
    """
    model = model.to(device=device)  # move the model parameters to CPU/GPU
    for e in range(epochs):
        for t, (x, y) in enumerate(loader_train):
            model.train()  # put model to training mode
            x = x.to(device=device, dtype=torch.float)  # move to device, e.g. GPU
            y = y.to(device=device, dtype=torch.long)

            scores = model(x)
            loss = F.cross_entropy(scores, y)

            # Zero out all of the gradients for the variables which the optimizer
            # will update.
            optimizer.zero_grad()

            # This is the backwards pass: compute the gradient of the loss with
            # respect to each  parameter of the model.
            loss.backward()

            # Actually update the parameters of the model using the gradients
            # computed by the backwards pass.
            optimizer.step()

            if t % print_every == 0:
                print('Iteration %d, loss = %.4f' % (t, loss.item()))
                check_accuracy_part34(loader_val, model)
                print()

# %%
################################################################################
# TODO:                                                                        #         
# Experiment with any architectures, optimizers, and hyperparameters.          #
# Achieve AT LEAST 70% accuracy on the *validation set* within 10 epochs.      #
#                                                                              #
# Note that you can use the check_accuracy function to evaluate on either      #
# the test set or the validation set, by passing either loader_test or         #
# loader_val as the second argument to check_accuracy. You should not touch    #
# the test set until you have finished your architecture and  hyperparameter   #
# tuning, and only run the test set once at the end to report a final value.   #
################################################################################
model = None
optimizer = None

# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****

import torch.nn.functional as F

class BasicBlock(nn.Module):
    expansion = 1

    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.shortcut = nn.Sequential()

        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class Bottleneck(nn.Module):

    expansion = 4

    def __init__(self, in_planes, planes, stride=1):
        super(Bottleneck, self).__init__()
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3,
                               stride=stride, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes)
        self.conv3 = nn.Conv2d(planes, self.expansion*planes,
                               kernel_size=1, bias=False)
        self.bn3 = nn.BatchNorm2d(self.expansion*planes)

        self.shortcut = nn.Sequential()
        if stride != 1 or in_planes != self.expansion*planes:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, self.expansion*planes,
                          kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion*planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = F.relu(self.bn2(self.conv2(out)))
        out = self.bn3(self.conv3(out))
        out += self.shortcut(x)
        out = F.relu(out)
        return out


class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        self.conv1 = nn.Conv2d(3, 64, kernel_size=3,
                               stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512*block.expansion, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1]*(num_blocks-1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


def ResNet18():
    return ResNet(BasicBlock, [2,2,2,2])

def ResNet34():
    return ResNet(BasicBlock, [3,4,6,3])

def ResNet50():
    return ResNet(Bottleneck, [3,4,6,3])

def ResNet101():
    return ResNet(Bottleneck, [3,4,23,3])

def ResNet152():
    return ResNet(Bottleneck, [3,8,36,3])

# model = ResNet34()
# optimizer = optim.Adam(model.parameters(), lr=1e-3)

# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                                 END OF YOUR CODE                             
################################################################################

# You should get at least 70% accuracy
# train_part34(model, optimizer, epochs=10)

# %%
# test which ResNet has the highest accuracy

# ResNet18
print('Training ResNet18...')
model = ResNet18()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
train_part34(model, optimizer, epochs=10)
print('ResNet18 has been trained')

# ResNet34
print('Training ResNet34...')
model = ResNet34()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
train_part34(model, optimizer, epochs=10)
print('ResNet34 has been trained')

# ResNet50
print('Training ResNet50...')
model = ResNet50()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
train_part34(model, optimizer, epochs=10)
print('ResNet50 has been trained')

# ResNet101
print('Training ResNet101...')
model = ResNet101()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
train_part34(model, optimizer, epochs=10)
print('ResNet101 has been trained')

# ResNet152
print('Training ResNet152...')
model = ResNet152()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
train_part34(model, optimizer, epochs=10)
print('ResNet152 has been trained')
# Out:
# Training ResNet18...
# Iteration 0, loss = 2.4753
# Checking accuracy on validation set
# Got 137 / 1000 correct (13.70)
#
# Iteration 100, loss = 1.5830
# Checking accuracy on validation set
# Got 347 / 1000 correct (34.70)
#
# Iteration 200, loss = 1.4220
# Checking accuracy on validation set
# Got 457 / 1000 correct (45.70)
#
# Iteration 300, loss = 1.3352
# Checking accuracy on validation set
# Got 500 / 1000 correct (50.00)
#
# Iteration 400, loss = 1.1313
# Checking accuracy on validation set
# Got 539 / 1000 correct (53.90)
#
# Iteration 500, loss = 1.0814
# Checking accuracy on validation set
# Got 564 / 1000 correct (56.40)
#
# Iteration 600, loss = 1.1486
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
#
# Iteration 700, loss = 1.3395
# Checking accuracy on validation set
# Got 606 / 1000 correct (60.60)
#
# Iteration 0, loss = 0.6734
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 100, loss = 1.1218
# Checking accuracy on validation set
# Got 620 / 1000 correct (62.00)
#
# Iteration 200, loss = 0.8034
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
#
# Iteration 300, loss = 0.7254
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
#
# Iteration 400, loss = 0.6823
# Checking accuracy on validation set
# Got 686 / 1000 correct (68.60)
#
# Iteration 500, loss = 0.7006
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 600, loss = 0.7369
# Checking accuracy on validation set
# Got 735 / 1000 correct (73.50)
#
# Iteration 700, loss = 0.6153
# Checking accuracy on validation set
# Got 746 / 1000 correct (74.60)
#
# Iteration 0, loss = 0.3804
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 100, loss = 0.8662
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Iteration 200, loss = 0.6092
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 300, loss = 1.0410
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
#
# Iteration 400, loss = 0.6142
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Iteration 500, loss = 0.5290
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Iteration 600, loss = 0.5751
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Iteration 700, loss = 0.3873
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Iteration 0, loss = 0.6420
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Iteration 100, loss = 0.3990
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Iteration 200, loss = 0.3457
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Iteration 300, loss = 0.5308
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Iteration 400, loss = 0.4149
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Iteration 500, loss = 0.4810
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Iteration 600, loss = 0.5103
# Checking accuracy on validation set
# Got 829 / 1000 correct (82.90)
#
# Iteration 700, loss = 0.4350
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 0, loss = 0.5105
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Iteration 100, loss = 0.2444
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Iteration 200, loss = 0.3837
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Iteration 300, loss = 0.4988
# Checking accuracy on validation set
# Got 805 / 1000 correct (80.50)
#
# Iteration 400, loss = 0.4288
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Iteration 500, loss = 0.6277
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Iteration 600, loss = 0.3683
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Iteration 700, loss = 0.2955
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Iteration 0, loss = 0.2164
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Iteration 100, loss = 0.2877
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Iteration 200, loss = 0.2059
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 300, loss = 0.2322
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Iteration 400, loss = 0.2153
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Iteration 500, loss = 0.3166
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Iteration 600, loss = 0.2371
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Iteration 700, loss = 0.2453
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Iteration 0, loss = 0.2260
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Iteration 100, loss = 0.1403
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Iteration 200, loss = 0.0675
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 300, loss = 0.0961
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Iteration 400, loss = 0.1849
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Iteration 500, loss = 0.1770
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 600, loss = 0.2762
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Iteration 700, loss = 0.3888
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Iteration 0, loss = 0.1225
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Iteration 100, loss = 0.0292
# Checking accuracy on validation set
# Got 860 / 1000 correct (86.00)
#
# Iteration 200, loss = 0.2297
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Iteration 300, loss = 0.2035
# Checking accuracy on validation set
# Got 859 / 1000 correct (85.90)
#
# Iteration 400, loss = 0.0255
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Iteration 500, loss = 0.0808
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Iteration 600, loss = 0.1102
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Iteration 700, loss = 0.0502
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Iteration 0, loss = 0.0262
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Iteration 100, loss = 0.0629
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Iteration 200, loss = 0.0669
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Iteration 300, loss = 0.3134
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Iteration 400, loss = 0.1416
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Iteration 500, loss = 0.1468
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Iteration 600, loss = 0.0407
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 700, loss = 0.1489
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Iteration 0, loss = 0.1153
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Iteration 100, loss = 0.0732
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Iteration 200, loss = 0.1257
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 300, loss = 0.0482
# Checking accuracy on validation set
# Got 851 / 1000 correct (85.10)
#
# Iteration 400, loss = 0.1139
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Iteration 500, loss = 0.0625
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Iteration 600, loss = 0.0458
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Iteration 700, loss = 0.1013
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# ResNet18 has been trained
# Training ResNet34...
# Iteration 0, loss = 2.4209
# Checking accuracy on validation set
# Got 87 / 1000 correct (8.70)
#
# Iteration 100, loss = 1.6491
# Checking accuracy on validation set
# Got 287 / 1000 correct (28.70)
#
# Iteration 200, loss = 1.5775
# Checking accuracy on validation set
# Got 401 / 1000 correct (40.10)
#
# Iteration 300, loss = 1.3947
# Checking accuracy on validation set
# Got 469 / 1000 correct (46.90)
#
# Iteration 400, loss = 1.4106
# Checking accuracy on validation set
# Got 467 / 1000 correct (46.70)
#
# Iteration 500, loss = 1.2854
# Checking accuracy on validation set
# Got 486 / 1000 correct (48.60)
#
# Iteration 600, loss = 1.1649
# Checking accuracy on validation set
# Got 521 / 1000 correct (52.10)
#
# Iteration 700, loss = 1.2122
# Checking accuracy on validation set
# Got 587 / 1000 correct (58.70)
#
# Iteration 0, loss = 1.0497
# Checking accuracy on validation set
# Got 603 / 1000 correct (60.30)
#
# Iteration 100, loss = 1.0906
# Checking accuracy on validation set
# Got 640 / 1000 correct (64.00)
#
# Iteration 200, loss = 1.1163
# Checking accuracy on validation set
# Got 605 / 1000 correct (60.50)
#
# Iteration 300, loss = 1.0584
# Checking accuracy on validation set
# Got 642 / 1000 correct (64.20)
#
# Iteration 400, loss = 0.8926
# Checking accuracy on validation set
# Got 638 / 1000 correct (63.80)
#
# Iteration 500, loss = 1.0433
# Checking accuracy on validation set
# Got 660 / 1000 correct (66.00)
#
# Iteration 600, loss = 0.7156
# Checking accuracy on validation set
# Got 670 / 1000 correct (67.00)
#
# Iteration 700, loss = 0.8387
# Checking accuracy on validation set
# Got 729 / 1000 correct (72.90)
#
# Iteration 0, loss = 0.8026
# Checking accuracy on validation set
# Got 708 / 1000 correct (70.80)
#
# Iteration 100, loss = 0.6030
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 200, loss = 0.6876
# Checking accuracy on validation set
# Got 684 / 1000 correct (68.40)
#
# Iteration 300, loss = 1.0282
# Checking accuracy on validation set
# Got 705 / 1000 correct (70.50)
#
# Iteration 400, loss = 0.5875
# Checking accuracy on validation set
# Got 750 / 1000 correct (75.00)
#
# Iteration 500, loss = 0.6637
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Iteration 600, loss = 0.4481
# Checking accuracy on validation set
# Got 766 / 1000 correct (76.60)
#
# Iteration 700, loss = 0.5871
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 0, loss = 0.4303
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Iteration 100, loss = 0.3869
# Checking accuracy on validation set
# Got 785 / 1000 correct (78.50)
#
# Iteration 200, loss = 0.7378
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
#
# Iteration 300, loss = 0.4618
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 400, loss = 0.6318
# Checking accuracy on validation set
# Got 797 / 1000 correct (79.70)
#
# Iteration 500, loss = 0.7192
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
#
# Iteration 600, loss = 0.3826
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Iteration 700, loss = 0.6646
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Iteration 0, loss = 0.4515
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Iteration 100, loss = 0.4235
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Iteration 200, loss = 0.4805
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Iteration 300, loss = 0.4129
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Iteration 400, loss = 0.4343
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Iteration 500, loss = 0.3628
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Iteration 600, loss = 0.5309
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Iteration 700, loss = 0.3649
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Iteration 0, loss = 0.2257
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Iteration 100, loss = 0.2857
# Checking accuracy on validation set
# Got 817 / 1000 correct (81.70)
#
# Iteration 200, loss = 0.5600
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 300, loss = 0.3037
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Iteration 400, loss = 0.3682
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Iteration 500, loss = 0.3260
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Iteration 600, loss = 0.3495
# Checking accuracy on validation set
# Got 840 / 1000 correct (84.00)
#
# Iteration 700, loss = 0.4001
# Checking accuracy on validation set
# Got 827 / 1000 correct (82.70)
#
# Iteration 0, loss = 0.2819
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Iteration 100, loss = 0.1276
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Iteration 200, loss = 0.2784
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Iteration 300, loss = 0.2057
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Iteration 400, loss = 0.1695
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# Iteration 500, loss = 0.1497
# Checking accuracy on validation set
# Got 832 / 1000 correct (83.20)
#
# Iteration 600, loss = 0.3909
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Iteration 700, loss = 0.2673
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Iteration 0, loss = 0.1732
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Iteration 100, loss = 0.1818
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Iteration 200, loss = 0.1238
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 300, loss = 0.1319
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 400, loss = 0.3099
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Iteration 500, loss = 0.3093
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Iteration 600, loss = 0.1678
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Iteration 700, loss = 0.1228
# Checking accuracy on validation set
# Got 850 / 1000 correct (85.00)
#
# Iteration 0, loss = 0.0764
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 100, loss = 0.0725
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 200, loss = 0.0600
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 300, loss = 0.1341
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Iteration 400, loss = 0.2304
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Iteration 500, loss = 0.1033
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Iteration 600, loss = 0.1370
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 700, loss = 0.0838
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 0, loss = 0.0636
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 100, loss = 0.0250
# Checking accuracy on validation set
# Got 868 / 1000 correct (86.80)
#
# Iteration 200, loss = 0.0459
# Checking accuracy on validation set
# Got 855 / 1000 correct (85.50)
#
# Iteration 300, loss = 0.1393
# Checking accuracy on validation set
# Got 847 / 1000 correct (84.70)
#
# Iteration 400, loss = 0.0686
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 500, loss = 0.0853
# Checking accuracy on validation set
# Got 837 / 1000 correct (83.70)
#
# Iteration 600, loss = 0.0774
# Checking accuracy on validation set
# Got 826 / 1000 correct (82.60)
#
# Iteration 700, loss = 0.1350
# Checking accuracy on validation set
# Got 863 / 1000 correct (86.30)
#
# ResNet34 has been trained
# Training ResNet50...
# Iteration 0, loss = 2.3713
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
#
# Iteration 100, loss = 1.7923
# Checking accuracy on validation set
# Got 338 / 1000 correct (33.80)
#
# Iteration 200, loss = 1.6737
# Checking accuracy on validation set
# Got 353 / 1000 correct (35.30)
#
# Iteration 300, loss = 1.4471
# Checking accuracy on validation set
# Got 450 / 1000 correct (45.00)
#
# Iteration 400, loss = 1.3120
# Checking accuracy on validation set
# Got 468 / 1000 correct (46.80)
#
# Iteration 500, loss = 1.3347
# Checking accuracy on validation set
# Got 493 / 1000 correct (49.30)
#
# Iteration 600, loss = 1.2600
# Checking accuracy on validation set
# Got 503 / 1000 correct (50.30)
#
# Iteration 700, loss = 1.0664
# Checking accuracy on validation set
# Got 586 / 1000 correct (58.60)
#
# Iteration 0, loss = 1.3168
# Checking accuracy on validation set
# Got 356 / 1000 correct (35.60)
# Iteration 100, loss = 0.9851
# Checking accuracy on validation set
# Got 579 / 1000 correct (57.90)
#
# Iteration 200, loss = 1.1819
# Checking accuracy on validation set
# Got 633 / 1000 correct (63.30)
#
# Iteration 300, loss = 1.0304
# Checking accuracy on validation set
# Got 581 / 1000 correct (58.10)
#
# Iteration 400, loss = 0.7835
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Iteration 500, loss = 1.0577
# Checking accuracy on validation set
# Got 589 / 1000 correct (58.90)
#
# Iteration 600, loss = 0.9911
# Checking accuracy on validation set
# Got 647 / 1000 correct (64.70)
#
# Iteration 700, loss = 0.7584
# Checking accuracy on validation set
# Got 665 / 1000 correct (66.50)
#
# Iteration 0, loss = 0.7834
# Checking accuracy on validation set
# Got 713 / 1000 correct (71.30)
#
# Iteration 100, loss = 0.8303
# Checking accuracy on validation set
# Got 706 / 1000 correct (70.60)
#
# Iteration 200, loss = 0.7497
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 300, loss = 0.8128
# Checking accuracy on validation set
# Got 709 / 1000 correct (70.90)
#
# Iteration 400, loss = 0.6105
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 500, loss = 0.6808
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 600, loss = 0.5157
# Checking accuracy on validation set
# Got 754 / 1000 correct (75.40)
#
# Iteration 700, loss = 0.5720
# Checking accuracy on validation set
# Got 716 / 1000 correct (71.60)
#
# Iteration 0, loss = 0.7507
# Checking accuracy on validation set
# Got 765 / 1000 correct (76.50)
#
# Iteration 100, loss = 0.3226
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 200, loss = 0.5412
# Checking accuracy on validation set
# Got 762 / 1000 correct (76.20)
#
# Iteration 300, loss = 0.5308
# Checking accuracy on validation set
# Got 758 / 1000 correct (75.80)
#
# Iteration 400, loss = 0.6673
# Checking accuracy on validation set
# Got 769 / 1000 correct (76.90)
#
# Iteration 500, loss = 0.5257
# Checking accuracy on validation set
# Got 724 / 1000 correct (72.40)
#
# Iteration 600, loss = 0.3760
# Checking accuracy on validation set
# Got 780 / 1000 correct (78.00)
#
# Iteration 700, loss = 0.5680
# Checking accuracy on validation set
# Got 763 / 1000 correct (76.30)
#
# Iteration 0, loss = 0.5325
# Checking accuracy on validation set
# Got 761 / 1000 correct (76.10)
#
# Iteration 100, loss = 0.4223
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Iteration 200, loss = 0.7499
# Checking accuracy on validation set
# Got 717 / 1000 correct (71.70)
#
# Iteration 300, loss = 0.4984
# Checking accuracy on validation set
# Got 792 / 1000 correct (79.20)
#
# Iteration 400, loss = 0.5339
# Checking accuracy on validation set
# Got 755 / 1000 correct (75.50)
#
# Iteration 500, loss = 0.4343
# Checking accuracy on validation set
# Got 795 / 1000 correct (79.50)
#
# Iteration 600, loss = 0.5219
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Iteration 700, loss = 0.5594
# Checking accuracy on validation set
# Got 818 / 1000 correct (81.80)
#
# Iteration 0, loss = 0.4252
# Checking accuracy on validation set
# Got 803 / 1000 correct (80.30)
#
# Iteration 100, loss = 0.5726
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Iteration 200, loss = 0.3760
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Iteration 300, loss = 0.2153
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Iteration 400, loss = 0.3608
# Checking accuracy on validation set
# Got 789 / 1000 correct (78.90)
#
# Iteration 500, loss = 0.3062
# Checking accuracy on validation set
# Got 815 / 1000 correct (81.50)
#
# Iteration 600, loss = 0.3383
# Checking accuracy on validation set
# Got 828 / 1000 correct (82.80)
#
# Iteration 700, loss = 0.3598
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 0, loss = 0.3387
# Checking accuracy on validation set
# Got 808 / 1000 correct (80.80)
#
# Iteration 100, loss = 0.2903
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 200, loss = 0.4335
# Checking accuracy on validation set
# Got 834 / 1000 correct (83.40)
#
# Iteration 300, loss = 0.4898
# Checking accuracy on validation set
# Got 835 / 1000 correct (83.50)
#
# Iteration 400, loss = 0.2877
# Checking accuracy on validation set
# Got 774 / 1000 correct (77.40)
#
# Iteration 500, loss = 0.4606
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Iteration 600, loss = 0.1833
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Iteration 700, loss = 0.2442
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Iteration 0, loss = 0.1033
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Iteration 100, loss = 0.1971
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Iteration 200, loss = 0.2190
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Iteration 300, loss = 0.2972
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Iteration 400, loss = 0.2498
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Iteration 500, loss = 0.3437
# Checking accuracy on validation set
# Got 839 / 1000 correct (83.90)
#
# Iteration 600, loss = 0.1592
# Checking accuracy on validation set
# Got 824 / 1000 correct (82.40)
#
# Iteration 700, loss = 0.2260
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Iteration 0, loss = 0.4462
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 100, loss = 0.2998
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 200, loss = 0.1832
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Iteration 300, loss = 0.1827
# Checking accuracy on validation set
# Got 836 / 1000 correct (83.60)
#
# Iteration 400, loss = 0.2793
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Iteration 500, loss = 0.1698
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# Iteration 600, loss = 0.3182
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Iteration 700, loss = 0.2924
# Checking accuracy on validation set
# Got 843 / 1000 correct (84.30)
#
# Iteration 0, loss = 0.2747
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Iteration 100, loss = 0.1229
# Checking accuracy on validation set
# Got 833 / 1000 correct (83.30)
#
# Iteration 200, loss = 0.0455
# Checking accuracy on validation set
# Got 852 / 1000 correct (85.20)
#
# Iteration 300, loss = 0.4156
# Checking accuracy on validation set
# Got 845 / 1000 correct (84.50)
#
# Iteration 400, loss = 0.1143
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Iteration 500, loss = 0.1444
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Iteration 600, loss = 0.1557
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 700, loss = 0.2112
# Checking accuracy on validation set
# Got 830 / 1000 correct (83.00)
#
# ResNet50 has been trained
# Training ResNet101...
# Iteration 0, loss = 2.3415
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
#
# Iteration 100, loss = 1.6848
# Checking accuracy on validation set
# Got 314 / 1000 correct (31.40)
#
# Iteration 200, loss = 1.6325
# Checking accuracy on validation set
# Got 364 / 1000 correct (36.40)
#
# Iteration 300, loss = 1.4331
# Checking accuracy on validation set
# Got 438 / 1000 correct (43.80)
#
# Iteration 400, loss = 1.8611
# Checking accuracy on validation set
# Got 421 / 1000 correct (42.10)
#
# Iteration 500, loss = 1.3512
# Checking accuracy on validation set
# Got 313 / 1000 correct (31.30)
#
# Iteration 600, loss = 1.4932
# Checking accuracy on validation set
# Got 424 / 1000 correct (42.40)
#
# Iteration 700, loss = 1.3845
# Checking accuracy on validation set
# Got 482 / 1000 correct (48.20)
#
# Iteration 0, loss = 1.3374
# Checking accuracy on validation set
# Got 535 / 1000 correct (53.50)
#
# Iteration 100, loss = 1.1074
# Checking accuracy on validation set
# Got 529 / 1000 correct (52.90)
#
# Iteration 200, loss = 1.8372
# Checking accuracy on validation set
# Got 321 / 1000 correct (32.10)
#
# Iteration 300, loss = 1.5105
# Checking accuracy on validation set
# Got 428 / 1000 correct (42.80)
#
# Iteration 400, loss = 1.6888
# Checking accuracy on validation set
# Got 366 / 1000 correct (36.60)
#
# Iteration 500, loss = 1.7600
# Checking accuracy on validation set
# Got 448 / 1000 correct (44.80)
#
# Iteration 600, loss = 1.0933
# Checking accuracy on validation set
# Got 512 / 1000 correct (51.20)
#
# Iteration 700, loss = 1.3337
# Checking accuracy on validation set
# Got 497 / 1000 correct (49.70)
#
# Iteration 0, loss = 1.2264
# Checking accuracy on validation set
# Got 498 / 1000 correct (49.80)
#
# Iteration 100, loss = 1.2261
# Checking accuracy on validation set
# Got 520 / 1000 correct (52.00)
#
# Iteration 200, loss = 1.4569
# Checking accuracy on validation set
# Got 607 / 1000 correct (60.70)
#
# Iteration 300, loss = 0.9405
# Checking accuracy on validation set
# Got 610 / 1000 correct (61.00)
#
# Iteration 400, loss = 1.1342
# Checking accuracy on validation set
# Got 621 / 1000 correct (62.10)
#
# Iteration 500, loss = 1.0395
# Checking accuracy on validation set
# Got 594 / 1000 correct (59.40)
#
# Iteration 600, loss = 0.9356
# Checking accuracy on validation set
# Got 606 / 1000 correct (60.60)
#
# Iteration 700, loss = 1.1859
# Checking accuracy on validation set
# Got 598 / 1000 correct (59.80)
#
# Iteration 0, loss = 0.8213
# Checking accuracy on validation set
# Got 645 / 1000 correct (64.50)
#
# Iteration 100, loss = 0.9933
# Checking accuracy on validation set
# Got 669 / 1000 correct (66.90)
#
# Iteration 200, loss = 0.8035
# Checking accuracy on validation set
# Got 692 / 1000 correct (69.20)
#
# Iteration 300, loss = 0.8583
# Checking accuracy on validation set
# Got 630 / 1000 correct (63.00)
#
# Iteration 400, loss = 0.7315
# Checking accuracy on validation set
# Got 643 / 1000 correct (64.30)
#
# Iteration 500, loss = 0.8927
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 600, loss = 1.0506
# Checking accuracy on validation set
# Got 712 / 1000 correct (71.20)
#
# Iteration 700, loss = 0.6129
# Checking accuracy on validation set
# Got 707 / 1000 correct (70.70)
#
# Iteration 0, loss = 0.6468
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 100, loss = 0.5382
# Checking accuracy on validation set
# Got 756 / 1000 correct (75.60)
#
# Iteration 200, loss = 0.7619
# Checking accuracy on validation set
# Got 679 / 1000 correct (67.90)
#
# Iteration 300, loss = 0.4754
# Checking accuracy on validation set
# Got 732 / 1000 correct (73.20)
#
# Iteration 400, loss = 0.7456
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 500, loss = 0.5923
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 600, loss = 0.6488
# Checking accuracy on validation set
# Got 782 / 1000 correct (78.20)
#
# Iteration 700, loss = 0.5920
# Checking accuracy on validation set
# Got 744 / 1000 correct (74.40)
#
# Iteration 0, loss = 0.3578
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Iteration 100, loss = 0.5267
# Checking accuracy on validation set
# Got 767 / 1000 correct (76.70)
#
# Iteration 200, loss = 0.5629
# Checking accuracy on validation set
# Got 776 / 1000 correct (77.60)
#
# Iteration 300, loss = 0.5578
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Iteration 400, loss = 0.7104
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Iteration 500, loss = 0.5182
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
#
# Iteration 600, loss = 0.6763
# Checking accuracy on validation set
# Got 725 / 1000 correct (72.50)
#
# Iteration 700, loss = 0.4906
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 0, loss = 0.3411
# Checking accuracy on validation set
# Got 773 / 1000 correct (77.30)
#
# Iteration 100, loss = 0.4285
# Checking accuracy on validation set
# Got 752 / 1000 correct (75.20)
#
# Iteration 200, loss = 0.4464
# Checking accuracy on validation set
# Got 814 / 1000 correct (81.40)
#
# Iteration 300, loss = 0.3867
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Iteration 400, loss = 0.3492
# Checking accuracy on validation set
# Got 779 / 1000 correct (77.90)
#
# Iteration 500, loss = 0.5741
# Checking accuracy on validation set
# Got 778 / 1000 correct (77.80)
#
# Iteration 600, loss = 0.4940
# Checking accuracy on validation set
# Got 793 / 1000 correct (79.30)
#
# Iteration 700, loss = 0.5748
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Iteration 0, loss = 0.5136
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Iteration 100, loss = 0.4013
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Iteration 200, loss = 0.3101
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 300, loss = 0.3981
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Iteration 400, loss = 0.5004
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Iteration 500, loss = 0.5190
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Iteration 600, loss = 0.5166
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 700, loss = 0.4669
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 0, loss = 0.4320
# Checking accuracy on validation set
# Got 800 / 1000 correct (80.00)
#
# Iteration 100, loss = 0.2873
# Checking accuracy on validation set
# Got 823 / 1000 correct (82.30)
#
# Iteration 200, loss = 0.4276
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 300, loss = 0.4653
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Iteration 400, loss = 0.3552
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 500, loss = 0.2263
# Checking accuracy on validation set
# Got 846 / 1000 correct (84.60)
#
# Iteration 600, loss = 0.3112
# Checking accuracy on validation set
# Got 811 / 1000 correct (81.10)
#
# Iteration 700, loss = 0.3673
# Checking accuracy on validation set
# Got 820 / 1000 correct (82.00)
#
# Iteration 0, loss = 0.2200
# Checking accuracy on validation set
# Got 842 / 1000 correct (84.20)
#
# Iteration 100, loss = 0.3184
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Iteration 200, loss = 0.3211
# Checking accuracy on validation set
# Got 822 / 1000 correct (82.20)
#
# Iteration 300, loss = 0.2715
# Checking accuracy on validation set
# Got 831 / 1000 correct (83.10)
#
# Iteration 400, loss = 0.2881
# Checking accuracy on validation set
# Got 825 / 1000 correct (82.50)
#
# Iteration 500, loss = 0.3736
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Iteration 600, loss = 0.2463
# Checking accuracy on validation set
# Got 849 / 1000 correct (84.90)
#
# Iteration 700, loss = 0.3469
# Checking accuracy on validation set
# Got 841 / 1000 correct (84.10)
#
# ResNet101 has been trained
# Training ResNet152...
# Iteration 0, loss = 2.7308
# Checking accuracy on validation set
# Got 119 / 1000 correct (11.90)
#
# Iteration 100, loss = 1.9730
# Checking accuracy on validation set
# Got 233 / 1000 correct (23.30)
#
# Iteration 200, loss = 1.8857
# Checking accuracy on validation set
# Got 203 / 1000 correct (20.30)
#
# Iteration 300, loss = 1.4232
# Checking accuracy on validation set
# Got 348 / 1000 correct (34.80)
#
# Iteration 400, loss = 1.4940
# Checking accuracy on validation set
# Got 338 / 1000 correct (33.80)
#
# Iteration 500, loss = 1.6108
# Checking accuracy on validation set
# Got 396 / 1000 correct (39.60)
#
# Iteration 600, loss = 1.4971
# Checking accuracy on validation set
# Got 386 / 1000 correct (38.60)
#
# Iteration 700, loss = 1.4369
# Checking accuracy on validation set
# Got 435 / 1000 correct (43.50)
#
# Iteration 0, loss = 1.6310
# Checking accuracy on validation set
# Got 385 / 1000 correct (38.50)
#
# Iteration 100, loss = 1.4638
# Checking accuracy on validation set
# Got 436 / 1000 correct (43.60)
#
# Iteration 200, loss = 1.3055
# Checking accuracy on validation set
# Got 469 / 1000 correct (46.90)
#
# Iteration 300, loss = 1.2898
# Checking accuracy on validation set
# Got 500 / 1000 correct (50.00)
#
# Iteration 400, loss = 1.2707
# Checking accuracy on validation set
# Got 567 / 1000 correct (56.70)
#
# Iteration 500, loss = 0.9024
# Checking accuracy on validation set
# Got 540 / 1000 correct (54.00)
#
# Iteration 600, loss = 1.0070
# Checking accuracy on validation set
# Got 528 / 1000 correct (52.80)
#
# Iteration 700, loss = 1.1343
# Checking accuracy on validation set
# Got 553 / 1000 correct (55.30)
#
# Iteration 0, loss = 1.3894
# Checking accuracy on validation set
# Got 583 / 1000 correct (58.30)
#
# Iteration 100, loss = 1.6398
# Checking accuracy on validation set
# Got 302 / 1000 correct (30.20)
# Iteration 200, loss = 1.1682
# Checking accuracy on validation set
# Got 581 / 1000 correct (58.10)
#
# Iteration 300, loss = 1.0978
# Checking accuracy on validation set
# Got 615 / 1000 correct (61.50)
#
# Iteration 400, loss = 0.8460
# Checking accuracy on validation set
# Got 581 / 1000 correct (58.10)
#
# Iteration 500, loss = 0.7462
# Checking accuracy on validation set
# Got 628 / 1000 correct (62.80)
#
# Iteration 600, loss = 1.0297
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Iteration 700, loss = 1.0411
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 0, loss = 0.8302
# Checking accuracy on validation set
# Got 663 / 1000 correct (66.30)
#
# Iteration 100, loss = 1.1100
# Checking accuracy on validation set
# Got 681 / 1000 correct (68.10)
#
# Iteration 200, loss = 0.9073
# Checking accuracy on validation set
# Got 694 / 1000 correct (69.40)
#
# Iteration 300, loss = 1.0113
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 400, loss = 0.6775
# Checking accuracy on validation set
# Got 700 / 1000 correct (70.00)
#
# Iteration 500, loss = 0.6889
# Checking accuracy on validation set
# Got 654 / 1000 correct (65.40)
#
# Iteration 600, loss = 0.7126
# Checking accuracy on validation set
# Got 674 / 1000 correct (67.40)
#
# Iteration 700, loss = 0.7399
# Checking accuracy on validation set
# Got 680 / 1000 correct (68.00)
#
# Iteration 0, loss = 0.5851
# Checking accuracy on validation set
# Got 697 / 1000 correct (69.70)
#
# Iteration 100, loss = 0.9464
# Checking accuracy on validation set
# Got 745 / 1000 correct (74.50)
#
# Iteration 200, loss = 0.6778
# Checking accuracy on validation set
# Got 736 / 1000 correct (73.60)
#
# Iteration 300, loss = 0.6310
# Checking accuracy on validation set
# Got 719 / 1000 correct (71.90)
#
# Iteration 400, loss = 0.9112
# Checking accuracy on validation set
# Got 739 / 1000 correct (73.90)
#
# Iteration 500, loss = 0.4932
# Checking accuracy on validation set
# Got 757 / 1000 correct (75.70)
#
# Iteration 600, loss = 0.8147
# Checking accuracy on validation set
# Got 742 / 1000 correct (74.20)
#
# Iteration 700, loss = 0.7871
# Checking accuracy on validation set
# Got 704 / 1000 correct (70.40)
#
# Iteration 0, loss = 0.5220
# Checking accuracy on validation set
# Got 751 / 1000 correct (75.10)
#
# Iteration 100, loss = 0.5655
# Checking accuracy on validation set
# Got 772 / 1000 correct (77.20)
#
# Iteration 200, loss = 0.4817
# Checking accuracy on validation set
# Got 771 / 1000 correct (77.10)
#
# Iteration 300, loss = 0.6483
# Checking accuracy on validation set
# Got 791 / 1000 correct (79.10)
#
# Iteration 400, loss = 0.6854
# Checking accuracy on validation set
# Got 726 / 1000 correct (72.60)
#
# Iteration 500, loss = 0.8967
# Checking accuracy on validation set
# Got 749 / 1000 correct (74.90)
#
# Iteration 600, loss = 0.5130
# Checking accuracy on validation set
# Got 790 / 1000 correct (79.00)
#
# Iteration 700, loss = 0.4753
# Checking accuracy on validation set
# Got 786 / 1000 correct (78.60)
#
# Iteration 0, loss = 0.7178
# Checking accuracy on validation set
# Got 673 / 1000 correct (67.30)
#
# Iteration 100, loss = 0.3481
# Checking accuracy on validation set
# Got 777 / 1000 correct (77.70)
#
# Iteration 200, loss = 0.7504
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Iteration 300, loss = 0.6491
# Checking accuracy on validation set
# Got 759 / 1000 correct (75.90)
#
# Iteration 400, loss = 0.5116
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 500, loss = 0.4482
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Iteration 600, loss = 0.4473
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Iteration 700, loss = 0.5077
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Iteration 0, loss = 0.3393
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Iteration 100, loss = 0.5048
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Iteration 200, loss = 0.5664
# Checking accuracy on validation set
# Got 806 / 1000 correct (80.60)
#
# Iteration 300, loss = 0.4631
# Checking accuracy on validation set
# Got 788 / 1000 correct (78.80)
#
# Iteration 400, loss = 0.5652
# Checking accuracy on validation set
# Got 799 / 1000 correct (79.90)
#
# Iteration 500, loss = 0.3501
# Checking accuracy on validation set
# Got 802 / 1000 correct (80.20)
#
# Iteration 600, loss = 0.3797
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 700, loss = 0.4266
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Iteration 0, loss = 0.2188
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Iteration 100, loss = 0.3663
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# Iteration 200, loss = 0.5675
# Checking accuracy on validation set
# Got 798 / 1000 correct (79.80)
#
# Iteration 300, loss = 0.2264
# Checking accuracy on validation set
# Got 796 / 1000 correct (79.60)
#
# Iteration 400, loss = 0.3350
# Checking accuracy on validation set
# Got 794 / 1000 correct (79.40)
#
# Iteration 500, loss = 0.3221
# Checking accuracy on validation set
# Got 816 / 1000 correct (81.60)
#
# Iteration 600, loss = 0.4629
# Checking accuracy on validation set
# Got 770 / 1000 correct (77.00)
#
# Iteration 700, loss = 0.6293
# Checking accuracy on validation set
# Got 804 / 1000 correct (80.40)
#
# Iteration 0, loss = 0.2912
# Checking accuracy on validation set
# Got 838 / 1000 correct (83.80)
#
# Iteration 100, loss = 0.3023
# Checking accuracy on validation set
# Got 821 / 1000 correct (82.10)
#
# Iteration 200, loss = 0.1412
# Checking accuracy on validation set
# Got 844 / 1000 correct (84.40)
#
# Iteration 300, loss = 0.2596
# Checking accuracy on validation set
# Got 809 / 1000 correct (80.90)
#
# Iteration 400, loss = 0.1897
# Checking accuracy on validation set
# Got 812 / 1000 correct (81.20)
#
# Iteration 500, loss = 0.2415
# Checking accuracy on validation set
# Got 819 / 1000 correct (81.90)
#
# Iteration 600, loss = 0.2934
# Checking accuracy on validation set
# Got 813 / 1000 correct (81.30)
#
# Iteration 700, loss = 0.2401
# Checking accuracy on validation set
# Got 810 / 1000 correct (81.00)
#
# ResNet152 has been trained

# %%
# ResNet18: 84.50
# ResNet34: 86.30
# ResNet50: 83.00
# ResNet101: 84.10
# ResNet152: 81.00
